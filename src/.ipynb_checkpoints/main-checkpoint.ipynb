# %% [markdown]
# # Eye classifier

# %% [markdown]
# The goals of this project are to build a classifier using CNN layers in a neural network in the first place, in order to classify images of eyes to figure out which one of them are opened, and which are closed, and then to create a regression to find the center of the pupil on the image. Such a tool could then be usefull in a biometric scanner, to account for human error in the handling of the scanner (blinking at the wrong time during the scan for example).

# %% [markdown]
# Our data is split in two folder, one containing closed eyes, and the other one containing opened eyes. Furthermore, the opened eyes folder is split in two sets, the train set and the test set, that will  come into play for thge regression task.

# %% [markdown]
# # Data exploration

# %% [markdown]
# Let's first take a look at our images.
#
# We will create an array containing all of our images, disregarding the distinciton between train and test images (from the open folder).

# %%
import os
import shutil

import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
open_imgs = []

for data_group in ['train', 'test']:
    imgs = os.listdir(f'data/open/{data_group}')
    for img_name in imgs:
        if img_name[-4:] == '.jpg':
            # Images come in shape (260, 400, 3), but are greyscale, so the component of shape 3 actually contains Lthe same number 3 times. So we only keep the first number.
            open_imgs.append(img_to_array(load_img(f'data/open/{data_group}/{img_name}'))[:,:,0:1] / 255)
open_imgs = np.array(open_imgs)

# %%
close_imgs = []

imgs = os.listdir('data/close')
for img_name in imgs:
    if img_name[-4:] == '.jpg':
        # Images come in shape (260, 400, 3), but are greyscale, so the component of shape 3 actually contains the same number 3 times. So we only keep the first number.
        close_imgs.append(img_to_array(load_img(f'data/close/{img_name}'))[:,:,0:1] / 255)
        
close_imgs = np.array(close_imgs)

# %%
all_imgs = np.concatenate([open_imgs, close_imgs])

# %%
# 907 images of size 260 * 400, in greyscale coded from 0 to 1.

print(all_imgs.shape)
print(all_imgs[0])
# Out:
# (907, 260, 400, 1)
# [[[0.02352941]
#   [0.00392157]
#   [0.06666667]
#   ...
#   [0.07450981]
#   [0.09411765]
#   [0.08627451]]
#
#  [[0.05882353]
#   [0.08235294]
#   [0.0627451 ]
#   ...
#   [0.09411765]
#   [0.09411765]
#   [0.12156863]]
#
#  [[0.09411765]
#   [0.08627451]
#   [0.04705882]
#   ...
#   [0.06666667]
#   [0.05098039]
#   [0.08627451]]
#
#  ...
#
#  [[0.04705882]
#   [0.07450981]
#   [0.08627451]
#   ...
#   [0.07450981]
#   [0.10196079]
#   [0.11372549]]
#
#  [[0.07450981]
#   [0.10196079]
#   [0.09019608]
#   ...
#   [0.14117648]
#   [0.0627451 ]
#   [0.06666667]]
#
#  [[0.08627451]
#   [0.04313726]
#   [0.05098039]
#   ...
#   [0.04313726]
#   [0.16862746]
#   [0.07450981]]]

# %%
# This snippet shows one image randomly taken from the list of all images.

plt.imshow(all_imgs[np.random.randint(0, len(all_imgs))], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# We have now all of our images. One important thing to notice is that the order in which they come in the array is that all opened eyes images come in first, and then all closed eyes images. This makes it very easy to create a list labelling all images as either opened eye or closed eye.

# %% [markdown]
# # Classification

# %% [markdown]
# First, we need to add labels to our images, for our classifier to have something to work on.

# %%
all_labels = np.array([1 for i in range(len(open_imgs))] + [0 for i in range(len(close_imgs))])

# %% [markdown]
# Then, we split our dataset between train and test.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(all_imgs, all_labels, test_size=0.2, random_state=0)

# %% [markdown]
# We now have to create our classifier. To achieve that, we will use the LetNet5 architecture.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Conv2D, Flatten, Dense

def model_clf():
    
    model = Sequential()
    
    model.add(Conv2D(filters=6, kernel_size=(3, 3), activation='relu', input_shape=(260,400,1)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    
    model.add(Dense(units=120, activation='relu'))
    model.add(Dense(units=84, activation='relu'))
    
    model.add(Dense(units=1, activation='sigmoid'))
    
    return model

# %%
model = model_clf()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 258, 398, 6)       60
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 129, 199, 6)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 127, 197, 16)      880
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 98, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 98784)             0
# _________________________________________________________________
# dense (Dense)                (None, 120)               11854200
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 11,865,389
# Trainable params: 11,865,389
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We can now train our network on our data.

# %%
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

callbacks = [EarlyStopping(monitor='val_loss', patience=5),
             TensorBoard(log_dir='./Graph_clf', histogram_freq=0, write_graph=True, write_images=True)]

# %%
# This snippet will remove any Graph folder preexisting
try:
    shutil.rmtree('./Graph_clf')
    print('Deleted')
except:
    pass

model.fit(x=X_train, 
          y=y_train, 
          validation_data=(X_test, y_test), 
          epochs=500, # With EarlyStopping, our training won't have to run this many epochs
          batch_size=64, 
          callbacks=callbacks)
# Out:
# Epoch 1/500
#  1/12 [=>............................] - ETA: 0s - loss: 0.6948 - accuracy: 0.2188WARNING:tensorflow:From /home/romaincaplier/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/12 [====>.........................] - ETA: 0s - loss: 0.7222 - accuracy: 0.2969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0196s vs `on_train_batch_end` time: 0.0348s). Check your callbacks.
# 12/12 [==============================] - 1s 70ms/step - loss: 0.7338 - accuracy: 0.5545 - val_loss: 0.5956 - val_accuracy: 0.7802
# Epoch 2/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.4735 - accuracy: 0.8221 - val_loss: 0.4120 - val_accuracy: 0.8626
# Epoch 3/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.3964 - accuracy: 0.8497 - val_loss: 0.3671 - val_accuracy: 0.8516
# Epoch 4/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.3370 - accuracy: 0.8593 - val_loss: 0.2941 - val_accuracy: 0.8791
# Epoch 5/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.2670 - accuracy: 0.8979 - val_loss: 0.2507 - val_accuracy: 0.9011
# Epoch 6/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.2043 - accuracy: 0.9159 - val_loss: 0.1867 - val_accuracy: 0.9121
# Epoch 7/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1464 - accuracy: 0.9407 - val_loss: 0.1233 - val_accuracy: 0.9670
# Epoch 8/500
# 12/12 [==============================] - 0s 39ms/step - loss: 0.1116 - accuracy: 0.9614 - val_loss: 0.1130 - val_accuracy: 0.9505
# Epoch 9/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0921 - accuracy: 0.9628 - val_loss: 0.1077 - val_accuracy: 0.9451
# Epoch 10/500
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0634 - accuracy: 0.9793 - val_loss: 0.0982 - val_accuracy: 0.9725
# Epoch 11/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0379 - accuracy: 0.9903 - val_loss: 0.0687 - val_accuracy: 0.9890
# Epoch 12/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0253 - accuracy: 0.9959 - val_loss: 0.0592 - val_accuracy: 0.9780
# Epoch 13/500
# 12/12 [==============================] - 0s 39ms/step - loss: 0.0165 - accuracy: 0.9972 - val_loss: 0.0973 - val_accuracy: 0.9725
# Epoch 14/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0101 - accuracy: 0.9986 - val_loss: 0.0632 - val_accuracy: 0.9780
# Epoch 15/500
# 12/12 [==============================] - 0s 39ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0838 - val_accuracy: 0.9780
# Epoch 16/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9835
# Epoch 17/500
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9835

# %%
# %load_ext tensorboard
# %tensorboard --logdir Graph_clf
# Out:
# Reusing TensorBoard on port 6009 (pid 29773), started 0:12:46 ago. (Use '!kill 29773' to kill it.)
#       <iframe id="tensorboard-frame-cafbccbe8da90f78" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cafbccbe8da90f78");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Let's now look at the performances of our model, by computing the prediction.

# %%
y_pred = np.rint(model.predict(X_test, batch_size=64, verbose=1)).astype('int').flatten()
# Out:
# 3/3 [==============================] - 0s 10ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98        67
#            1       0.98      0.99      0.99       115
#
#     accuracy                           0.98       182
#    macro avg       0.98      0.98      0.98       182
# weighted avg       0.98      0.98      0.98       182

# %% [markdown]
# Our model gives us 98% accuracy, and 98% f1, which is a good result.
#
# Theses number could be improved by tweaking the model.

# %% [markdown]
# # Regression

# %% [markdown]
# We now only consider images of opened eyes (as finding the center of the pupil is quite impossible when the pupil isn't even on the image). These images are split in two sets, one training set and one testing set. These two folder also contain one csv each, which gives us the position of the center of the pupil. As it is what we are trying to predict, we will first load them in dataframes.

# %%
import pandas as pd

centers_train = pd.read_csv('data/open/train/dataPupilCenterTrain.csv').drop('id', axis=1)
centers_test = pd.read_csv('data/open/test/dataPupilCenterTest.csv').drop('id', axis=1)

# %%
centers_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   xcentral  480 non-null    object
#  1   ycentral  480 non-null    object
# dtypes: object(2)
# memory usage: 7.6+ KB

# %%
centers_train['xcentral'].value_counts()
# Out:
# ?      49
# 225     6
# 259     6
# 138     6
# 216     6
#        ..
# 360     1
# 106     1
# 154     1
# 374     1
# 335     1
# Name: xcentral, Length: 195, dtype: int64

# %% [markdown]
# We can see here that there are a lines where the center position isn't given. We cannot use the corresponding images, so we will have to purge them from our dataset.
#
# We will remove every image that has at least one unknown center coordinate (even in our testing set, because these centers need to be known to be able to evaluate the performance of our model).

# %%
# We create the list of id of the bad images.

bad_train_imgs_ids = centers_train.loc[~ centers_train['xcentral'].str.isnumeric() | ~ centers_train['ycentral'].str.isnumeric()].index
bad_test_imgs_ids = centers_test.loc[~ centers_test['xcentral'].str.isnumeric() | ~ centers_test['ycentral'].str.isnumeric()].index

# %%
# We drop all corresponding images

centers_train.drop(bad_train_imgs_ids, axis=0, inplace=True)
centers_test.drop(bad_test_imgs_ids, axis=0, inplace=True)

# %%
# We convert all strings into numbers

centers_train = centers_train.astype('int')
centers_test = centers_test.astype('int')

# %% [markdown]
# Now that we know which images we can keep, we can build our two new image arrays.

# %%
train_imgs = []

imgs = os.listdir('data/open/train')
for img_name in imgs:
    if img_name[-4:] == '.jpg' and int(''.join([c for c in img_name if c.isdigit()])) not in bad_train_imgs_ids:
        index = int(''.join([c for c in img_name if c.isdigit()]))
        # Images come in shape (260, 400, 3), but are greyscale, so the component of shape 3 actually contains Lthe same number 3 times. So we only keep the first number.
        train_imgs.append([index, img_to_array(load_img(f'data/open/train/{img_name}'))[:,:,0:1] / 255])

train_imgs = np.stack(np.array(sorted(np.array(train_imgs), key=lambda img: img[0]))[:,1], axis=0)

# %%
test_imgs = []

imgs = os.listdir('data/open/test')
for img_name in imgs:
    if img_name[-4:] == '.jpg' and int(''.join([c for c in img_name if c.isdigit()])) not in bad_test_imgs_ids:
        index = int(''.join([c for c in img_name if c.isdigit()]))
        # Images come in shape (260, 400, 3), but are greyscale, so the component of shape 3 actually contains Lthe same number 3 times. So we only keep the first number.
        test_imgs.append([index, img_to_array(load_img(f'data/open/test/{img_name}'))[:,:,0:1] / 255])

test_imgs = np.stack(np.array(sorted(np.array(test_imgs), key=lambda img: img[0]))[:,1], axis=0)

# %% [markdown]
# We can now build our model. Here, we will still use the same basic architecture as used above.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Conv2D, Flatten, Dense
from tensorflow.keras import regularizers

def model_reg(regul=0.00):
    
    model = Sequential()
    
    model.add(Conv2D(filters=6, kernel_size=(3, 3), activation='relu', input_shape=(260,400,1)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    
    model.add(Dense(units=120, activation='relu', kernel_regularizer=regularizers.l2(regul)))
    model.add(Dense(units=84, activation='relu', kernel_regularizer=regularizers.l2(regul)))
    
    model.add(Dense(units=2, activation='linear'))
    
    return model

# %%
model = model_reg(0.01)
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 258, 398, 6)       60
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 129, 199, 6)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 127, 197, 16)      880
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 63, 98, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 98784)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               11854200
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 170
# =================================================================
# Total params: 11,865,474
# Trainable params: 11,865,474
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

callbacks = [EarlyStopping(monitor='val_loss', patience=30),
             TensorBoard(log_dir='./Graph_reg', histogram_freq=0, write_graph=True, write_images=True)]

# %%
# This snippet will remove any Graph folder preexisting
try:
    shutil.rmtree('./Graph_reg')
    print('Deleted')
except:
    pass

model.fit(x=train_imgs, 
          y=centers_train.values, 
          validation_data=(test_imgs, centers_test.values), 
          epochs=200,
          batch_size=64, 
          callbacks=callbacks)
# Out:
# Epoch 1/200
# 2/7 [=======>......................] - ETA: 0s - loss: 34875.7891WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0194s vs `on_train_batch_end` time: 0.0919s). Check your callbacks.
# 7/7 [==============================] - 1s 96ms/step - loss: 26767.8379 - val_loss: 5179.8506
# Epoch 2/200
# 7/7 [==============================] - 0s 38ms/step - loss: 8420.3994 - val_loss: 14101.2471
# Epoch 3/200
# 7/7 [==============================] - 0s 38ms/step - loss: 6060.6938 - val_loss: 3708.8906
# Epoch 4/200
# 7/7 [==============================] - 0s 38ms/step - loss: 5568.7241 - val_loss: 9080.1494
# Epoch 5/200
# 7/7 [==============================] - 0s 38ms/step - loss: 4596.7651 - val_loss: 5173.5718
# Epoch 6/200
# 7/7 [==============================] - 0s 38ms/step - loss: 3680.1184 - val_loss: 4956.5479
# Epoch 7/200
# 7/7 [==============================] - 0s 38ms/step - loss: 2984.4148 - val_loss: 4555.6152
# Epoch 8/200
# 7/7 [==============================] - 0s 38ms/step - loss: 2587.6526 - val_loss: 4108.9443
# Epoch 9/200
# 7/7 [==============================] - 0s 38ms/step - loss: 2257.2261 - val_loss: 4263.6069
# Epoch 10/200
# 7/7 [==============================] - 0s 39ms/step - loss: 1857.9740 - val_loss: 4732.3882
# Epoch 11/200
# 7/7 [==============================] - 0s 37ms/step - loss: 1563.9640 - val_loss: 4729.8623
# Epoch 12/200
# 7/7 [==============================] - 0s 38ms/step - loss: 1408.9048 - val_loss: 4718.1929
# Epoch 13/200
# 7/7 [==============================] - 0s 37ms/step - loss: 1312.1384 - val_loss: 4616.7622
# Epoch 14/200
# 7/7 [==============================] - 0s 38ms/step - loss: 1220.3589 - val_loss: 5246.3135
# Epoch 15/200
# 7/7 [==============================] - 0s 38ms/step - loss: 1132.5051 - val_loss: 4564.6523
# Epoch 16/200
# 7/7 [==============================] - 0s 37ms/step - loss: 1040.9172 - val_loss: 4741.4395
# Epoch 17/200
# 7/7 [==============================] - 0s 38ms/step - loss: 1009.7599 - val_loss: 4385.5327
# Epoch 18/200
# 7/7 [==============================] - 0s 39ms/step - loss: 930.2594 - val_loss: 4802.8374
# Epoch 19/200
# 7/7 [==============================] - 0s 39ms/step - loss: 860.0590 - val_loss: 4657.6978
# Epoch 20/200
# 7/7 [==============================] - 0s 37ms/step - loss: 812.1399 - val_loss: 4209.6255
# Epoch 21/200
# 7/7 [==============================] - 0s 39ms/step - loss: 746.5086 - val_loss: 3897.8765
# Epoch 22/200
# 7/7 [==============================] - 0s 38ms/step - loss: 669.7084 - val_loss: 4484.1729
# Epoch 23/200
# 7/7 [==============================] - 0s 38ms/step - loss: 612.4496 - val_loss: 3922.7195
# Epoch 24/200
# 7/7 [==============================] - 0s 39ms/step - loss: 565.7861 - val_loss: 4196.1860
# Epoch 25/200
# 7/7 [==============================] - 0s 38ms/step - loss: 519.5983 - val_loss: 4038.3918
# Epoch 26/200
# 7/7 [==============================] - 0s 38ms/step - loss: 478.3218 - val_loss: 4403.3579
# Epoch 27/200
# 7/7 [==============================] - 0s 38ms/step - loss: 453.6722 - val_loss: 4282.9946
# Epoch 28/200
# 7/7 [==============================] - 0s 40ms/step - loss: 424.3902 - val_loss: 3872.9341
# Epoch 29/200
# 7/7 [==============================] - 0s 38ms/step - loss: 402.4996 - val_loss: 4013.5183
# Epoch 30/200
# 7/7 [==============================] - 0s 38ms/step - loss: 367.7022 - val_loss: 4344.0664
# Epoch 31/200
# 7/7 [==============================] - 0s 38ms/step - loss: 346.7273 - val_loss: 4545.4136
# Epoch 32/200
# 7/7 [==============================] - 0s 38ms/step - loss: 323.3583 - val_loss: 4336.9712
# Epoch 33/200
# 7/7 [==============================] - 0s 38ms/step - loss: 300.2025 - val_loss: 4506.1172

# %%
# %load_ext tensorboard
# %tensorboard --logdir Graph_reg
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6010 (pid 30431), started 0:11:10 ago. (Use '!kill 30431' to kill it.)
#       <iframe id="tensorboard-frame-c95020d6241b5abe" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c95020d6241b5abe");
#           const url = new URL("/", window.location);
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# We see here that our model is overfitting vastly. Let's look at the predicted result, first on our train dataset, and then on our test dataset

# %%
y_pred_train = model.predict(train_imgs)

# %%
# Display the results for some eyes
index = np.random.randint(0, len(train_imgs))

# Image to display
display = train_imgs[index]
center_pred = y_pred_train[index]
center_true = centers_train.values[index]

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(display, cmap='gray')

# Draw the true and the predicted centers
point_pred = plt.scatter(center_pred[0], center_pred[1], marker='*', c='yellow')
point_true = plt.scatter(center_true[0], center_true[1], marker='*', c='red')

plt.axis('off')
plt.show()

# %%
y_pred_test = model.predict(test_imgs)

# %%
# Display the results for some eyes
index = np.random.randint(0, len(test_imgs))

# Image to display
display = test_imgs[index]
center_pred = y_pred_test[index]
center_true = centers_test.values[index]

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(display, cmap='gray')

# Draw the true and the predicted centers
point_pred = plt.scatter(center_pred[0], center_pred[1], marker='*', c='yellow')
point_true = plt.scatter(center_true[0], center_true[1], marker='*', c='red')

plt.axis('off')
plt.show()

# %% [markdown]
# As we can see, even if the train daataset provides us with reasonably good results, the performance on our test dataset is pretty poor.
#
# To improve this projet, overfitting should be the focus. To reduce it, adding regularization, or improving the model would help out a lot.
